# %%
# !pip install librosa
# !pip install soundfile
# Out:
# Collecting librosa
#   Downloading librosa-0.10.0.post2-py3-none-any.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 952.5 kB/s eta 0:00:00a 0:00:01
# Collecting soxr>=0.3.2
#   Downloading soxr-0.3.5-cp310-cp310-macosx_10_9_x86_64.whl (404 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.5/404.5 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: decorator>=4.3.0 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from librosa) (0.56.4)
# Requirement already satisfied: scipy>=1.2.0 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from librosa) (1.10.0)
# Requirement already satisfied: pooch<1.7,>=1.0 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from librosa) (1.4.0)
# Collecting soundfile>=0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-macosx_10_9_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 2.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from librosa) (4.4.0)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 3.0 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from librosa) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from librosa) (1.2.1)
# Requirement already satisfied: msgpack>=1.0 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: joblib>=0.14 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from librosa) (1.1.1)
# Collecting lazy-loader>=0.1
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: setuptools in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (65.6.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: appdirs in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from pooch<1.7,>=1.0->librosa) (2.28.1)
# Requirement already satisfied: packaging in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from pooch<1.7,>=1.0->librosa) (22.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from requests->pooch<1.7,>=1.0->librosa) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from requests->pooch<1.7,>=1.0->librosa) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from requests->pooch<1.7,>=1.0->librosa) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from requests->pooch<1.7,>=1.0->librosa) (2022.12.7)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23704 sha256=7c6244c6f1e736a25db706e4ce674e374527034a23ac1381be67139a1da2b001
#   Stored in directory: /Users/zarinamacbook/Library/Caches/pip/wheels/3d/e0/4b/51b8aa4a0e2b6361c14943f7a7c2c7adb7b9cd419e0a1b720d
# Successfully built audioread
# Installing collected packages: soxr, lazy-loader, audioread, soundfile, librosa
# Successfully installed audioread-3.0.0 lazy-loader-0.3 librosa-0.10.0.post2 soundfile-0.12.1 soxr-0.3.5
# Requirement already satisfied: soundfile in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from cffi>=1.0->soundfile) (2.21)

# %%
# !pip install pydub
# Out:
# Requirement already satisfied: pydub in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (0.25.1)

# %%
import os
import csv
from pydub import AudioSegment
from pydub.silence import split_on_silence

def split_audio_by_silence(audio_path, min_silence_duration_ms, silence_threshold=-50):
    audio = AudioSegment.from_file(audio_path)

    # Split the audio file into fragments based on silence
    audio_fragments = split_on_silence(audio, min_silence_len=min_silence_duration_ms, silence_thresh=silence_threshold)

    return audio_fragments

# Define the audio file path and minimum silence duration
audio_path = '/Users/zarinamacbook/Desktop/Internship/DataAudio/01_Proba.wav'
min_silence_duration_ms = 300  # Minimum silence duration in milliseconds (1 second)

# Split the audio into fragments
fragments = split_audio_by_silence(audio_path, min_silence_duration_ms)

# Specify the dataset folder and CSV file path
dataset_folder = 'datasetm'
csv_file = 'datasetm.csv'

# Create the dataset folder if it doesn't exist
if not os.path.exists(dataset_folder):
    os.makedirs(dataset_folder)

# Open the CSV file in write mode
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Filename', 'Duration'])  # Write header row

    # Save the fragments as WAV files and write metadata to the CSV file
    for i, fragment in enumerate(fragments):
        # Generate a unique filename for the fragment
        fragment_filename = f"fragment_{i+1}.wav"
        fragment_path = os.path.join(dataset_folder, fragment_filename)

        # Export the fragment as a WAV file
        fragment.export(fragment_path, format="wav")
        print(f"Fragment {i+1} saved as {fragment_path}")

        # Write fragment metadata to the CSV file
        duration = len(fragment) / 1000.0  # Duration in seconds
        writer.writerow([fragment_filename, duration])

print("Dataset creation complete.")
# Out:
# Fragment 1 saved as datasetm/fragment_1.wav
# Fragment 2 saved as datasetm/fragment_2.wav
# Fragment 3 saved as datasetm/fragment_3.wav
# Fragment 4 saved as datasetm/fragment_4.wav
# Fragment 5 saved as datasetm/fragment_5.wav
# Fragment 6 saved as datasetm/fragment_6.wav
# Fragment 7 saved as datasetm/fragment_7.wav
# Fragment 8 saved as datasetm/fragment_8.wav
# Fragment 9 saved as datasetm/fragment_9.wav
# Fragment 10 saved as datasetm/fragment_10.wav
# Fragment 11 saved as datasetm/fragment_11.wav
# Fragment 12 saved as datasetm/fragment_12.wav
# Fragment 13 saved as datasetm/fragment_13.wav
# Fragment 14 saved as datasetm/fragment_14.wav
# Fragment 15 saved as datasetm/fragment_15.wav
# Fragment 16 saved as datasetm/fragment_16.wav
# Fragment 17 saved as datasetm/fragment_17.wav
# Fragment 18 saved as datasetm/fragment_18.wav
# Fragment 19 saved as datasetm/fragment_19.wav
# Fragment 20 saved as datasetm/fragment_20.wav
# Fragment 21 saved as datasetm/fragment_21.wav
# Fragment 22 saved as datasetm/fragment_22.wav
# Fragment 23 saved as datasetm/fragment_23.wav
# Fragment 24 saved as datasetm/fragment_24.wav
# Fragment 25 saved as datasetm/fragment_25.wav
# Fragment 26 saved as datasetm/fragment_26.wav
# Fragment 27 saved as datasetm/fragment_27.wav
# Fragment 28 saved as datasetm/fragment_28.wav
# Fragment 29 saved as datasetm/fragment_29.wav
# Fragment 30 saved as datasetm/fragment_30.wav
# Fragment 31 saved as datasetm/fragment_31.wav
# Fragment 32 saved as datasetm/fragment_32.wav
# Fragment 33 saved as datasetm/fragment_33.wav
# Fragment 34 saved as datasetm/fragment_34.wav
# Fragment 35 saved as datasetm/fragment_35.wav
# Fragment 36 saved as datasetm/fragment_36.wav
# Fragment 37 saved as datasetm/fragment_37.wav
# Fragment 38 saved as datasetm/fragment_38.wav
# Fragment 39 saved as datasetm/fragment_39.wav
# Fragment 40 saved as datasetm/fragment_40.wav
# Fragment 41 saved as datasetm/fragment_41.wav
# Fragment 42 saved as datasetm/fragment_42.wav
# Fragment 43 saved as datasetm/fragment_43.wav
# Fragment 44 saved as datasetm/fragment_44.wav
# Fragment 45 saved as datasetm/fragment_45.wav
# Fragment 46 saved as datasetm/fragment_46.wav
# Fragment 47 saved as datasetm/fragment_47.wav
# Fragment 48 saved as datasetm/fragment_48.wav
# Fragment 49 saved as datasetm/fragment_49.wav
# Fragment 50 saved as datasetm/fragment_50.wav
# Fragment 51 saved as datasetm/fragment_51.wav
# Fragment 52 saved as datasetm/fragment_52.wav
# Fragment 53 saved as datasetm/fragment_53.wav
# Fragment 54 saved as datasetm/fragment_54.wav
# Fragment 55 saved as datasetm/fragment_55.wav
# Fragment 56 saved as datasetm/fragment_56.wav
# Fragment 57 saved as datasetm/fragment_57.wav
# Fragment 58 saved as datasetm/fragment_58.wav
# Fragment 59 saved as datasetm/fragment_59.wav
# Fragment 60 saved as datasetm/fragment_60.wav
# Fragment 61 saved as datasetm/fragment_61.wav
# Fragment 62 saved as datasetm/fragment_62.wav
# Fragment 63 saved as datasetm/fragment_63.wav
# Fragment 64 saved as datasetm/fragment_64.wav
# Fragment 65 saved as datasetm/fragment_65.wav
# Fragment 66 saved as datasetm/fragment_66.wav
# Fragment 67 saved as datasetm/fragment_67.wav
# Fragment 68 saved as datasetm/fragment_68.wav
# Fragment 69 saved as datasetm/fragment_69.wav
# Fragment 70 saved as datasetm/fragment_70.wav
# Fragment 71 saved as datasetm/fragment_71.wav
# Fragment 72 saved as datasetm/fragment_72.wav
# Fragment 73 saved as datasetm/fragment_73.wav
# Fragment 74 saved as datasetm/fragment_74.wav
# Fragment 75 saved as datasetm/fragment_75.wav
# Fragment 76 saved as datasetm/fragment_76.wav
# Fragment 77 saved as datasetm/fragment_77.wav
# Fragment 78 saved as datasetm/fragment_78.wav
# Dataset creation complete.

# %%
# !pip install ffmpeg-python
# Out:
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages (from ffmpeg-python) (0.18.3)
# Installing collected packages: ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0

# %%
import os
import csv
from pydub import AudioSegment
from pydub.silence import split_on_silence

def split_audio_by_silence(audio_path, min_silence_duration_ms, silence_threshold=-50):
    audio = AudioSegment.from_file(audio_path)

    # Split the audio file into fragments based on silence
    audio_fragments = split_on_silence(audio, min_silence_len=min_silence_duration_ms, silence_thresh=silence_threshold)

    return audio_fragments

# Define the audio file path and minimum silence duration
audio_path = '/Users/zarinamacbook/Desktop/Internship/DataAudio/02_str_Zhensk.wav'
min_silence_duration_ms = 500  # Minimum silence duration in milliseconds (1 second)

# Split the audio into fragments
fragments = split_audio_by_silence(audio_path, min_silence_duration_ms)

# Specify the dataset folder and CSV file path
dataset_folder = 'datasetzh'
csv_file = 'datasetzh.csv'

# Create the dataset folder if it doesn't exist
if not os.path.exists(dataset_folder):
    os.makedirs(dataset_folder)

# Open the CSV file in write mode
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Filename', 'Duration'])  # Write header row

    # Save the fragments as WAV files and write metadata to the CSV file
    for i, fragment in enumerate(fragments):
        # Generate a unique filename for the fragment
        fragment_filename = f"fragment_{i+1}.wav"
        fragment_path = os.path.join(dataset_folder, fragment_filename)

        # Export the fragment as a WAV file
        fragment.export(fragment_path, format="wav")
        print(f"Fragment {i+1} saved as {fragment_path}")

        # Write fragment metadata to the CSV file
        duration = len(fragment) / 1000.0  # Duration in seconds
        writer.writerow([fragment_filename, duration])

print("Dataset creation complete.")
# Out:
# /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages/pydub/utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 19
#      16 min_silence_duration_ms = 500  # Minimum silence duration in milliseconds (1 second)
#      18 # Split the audio into fragments
# ---> 19 fragments = split_audio_by_silence(audio_path, min_silence_duration_ms)
#      21 # Specify the dataset folder and CSV file path
#      22 dataset_folder = 'datasetzh'
#
# Cell In[11], line 7, in split_audio_by_silence(audio_path, min_silence_duration_ms, silence_threshold)
#       6 def split_audio_by_silence(audio_path, min_silence_duration_ms, silence_threshold=-50):
# ----> 7     audio = AudioSegment.from_file(audio_path)
#       9     # Split the audio file into fragments based on silence
#      10     audio_fragments = split_on_silence(audio, min_silence_len=min_silence_duration_ms, silence_thresh=silence_threshold)
#
# File ~/anaconda3/lib/python3.10/site-packages/pydub/audio_segment.py:728, in AudioSegment.from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     726     info = None
#     727 else:
# --> 728     info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#     729 if info:
#     730     audio_streams = [x for x in info['streams']
#     731                      if x['codec_type'] == 'audio']
#
# File ~/anaconda3/lib/python3.10/site-packages/pydub/utils.py:274, in mediainfo_json(filepath, read_ahead_limit)
#     271         file.close()
#     273 command = [prober, '-of', 'json'] + command_args
# --> 274 res = Popen(command, stdin=stdin_parameter, stdout=PIPE, stderr=PIPE)
#     275 output, stderr = res.communicate(input=stdin_data)
#     276 output = output.decode("utf-8", 'ignore')
#
# File ~/anaconda3/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     967         if self.text_mode:
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#     982     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/anaconda3/lib/python3.10/subprocess.py:1847, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1845     if errno_num != 0:
#    1846         err_msg = os.strerror(errno_num)
# -> 1847     raise child_exception_type(errno_num, err_msg, err_filename)
#    1848 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ffprobe'

# %%
import os
import csv
from pydub import AudioSegment
from pydub.silence import split_on_silence

def split_audio_by_silence(audio_path, min_silence_duration_ms, silence_threshold=-50):
    audio = AudioSegment.from_file(audio_path, format="wav", parameters=["-ar", "16000"], ffprobe="/path/to/ffprobe")

    # Split the audio file into fragments based on silence
    audio_fragments = split_on_silence(audio, min_silence_len=min_silence_duration_ms, silence_thresh=silence_threshold, seek_step=1, keep_silence=100)

    return audio_fragments

# Define the audio file path and minimum silence duration
audio_path = '/Users/zarinamacbook/Desktop/Internship/DataAudio/01_strZhensk.wav'
min_silence_duration_ms = 1000  # Minimum silence duration in milliseconds (1 second)

# Split the audio into fragments
fragments = split_audio_by_silence(audio_path, min_silence_duration_ms)

# Specify the dataset folder and CSV file path
dataset_folder = 'dataset'
csv_file = 'dataset.csv'

# Create the dataset folder if it doesn't exist
if not os.path.exists(dataset_folder):
    os.makedirs(dataset_folder)

# Open the CSV file in write mode with UTF-8 encoding
with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Filename', 'Duration'])  # Write header row

    # Save the fragments as WAV files and write metadata to the CSV file
    for i, fragment in enumerate(fragments):
        # Generate a unique filename for the fragment
        fragment_filename = f"fragment_{i+1}.wav"
        fragment_path = os.path.join(dataset_folder, fragment_filename)

        # Export the fragment as a WAV file
        fragment.export(fragment_path, format="wav")
        print(f"Fragment {i+1} saved as {fragment_path}")

        # Write fragment metadata to the CSV file
        duration = len(fragment) / 1000.0  # Duration in seconds
# Out:
# /Users/zarinamacbook/anaconda3/lib/python3.10/site-packages/pydub/utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 19
#      16 min_silence_duration_ms = 1000  # Minimum silence duration in milliseconds (1 second)
#      18 # Split the audio into fragments
# ---> 19 fragments = split_audio_by_silence(audio_path, min_silence_duration_ms)
#      21 # Specify the dataset folder and CSV file path
#      22 dataset_folder = 'dataset'
#
# Cell In[15], line 7, in split_audio_by_silence(audio_path, min_silence_duration_ms, silence_threshold)
#       6 def split_audio_by_silence(audio_path, min_silence_duration_ms, silence_threshold=-50):
# ----> 7     audio = AudioSegment.from_file(audio_path, format="wav", parameters=["-ar", "16000"], ffprobe="/path/to/ffprobe")
#       9     # Split the audio file into fragments based on silence
#      10     audio_fragments = split_on_silence(audio, min_silence_len=min_silence_duration_ms, silence_thresh=silence_threshold, seek_step=1, keep_silence=100)
#
# File ~/anaconda3/lib/python3.10/site-packages/pydub/audio_segment.py:728, in AudioSegment.from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     726     info = None
#     727 else:
# --> 728     info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#     729 if info:
#     730     audio_streams = [x for x in info['streams']
#     731                      if x['codec_type'] == 'audio']
#
# File ~/anaconda3/lib/python3.10/site-packages/pydub/utils.py:274, in mediainfo_json(filepath, read_ahead_limit)
#     271         file.close()
#     273 command = [prober, '-of', 'json'] + command_args
# --> 274 res = Popen(command, stdin=stdin_parameter, stdout=PIPE, stderr=PIPE)
#     275 output, stderr = res.communicate(input=stdin_data)
#     276 output = output.decode("utf-8", 'ignore')
#
# File ~/anaconda3/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     967         if self.text_mode:
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#     982     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/anaconda3/lib/python3.10/subprocess.py:1847, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1845     if errno_num != 0:
#    1846         err_msg = os.strerror(errno_num)
# -> 1847     raise child_exception_type(errno_num, err_msg, err_filename)
#    1848 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ffprobe'

# %%
import os
import csv
from pydub import AudioSegment
from pydub.silence import split_on_silence

def split_audio_by_silence(audio_path, min_silence_duration_ms, silence_threshold=-50):
    audio = AudioSegment.from_file(audio_path)

    # Split the audio file into fragments based on silence
    audio_fragments = split_on_silence(audio, min_silence_len=min_silence_duration_ms, silence_thresh=silence_threshold)

    return audio_fragments

# Define the audio file path and minimum silence duration
audio_path = '/Users/zarinamacbook/Desktop/Internship/DataAudio/M_5_str.wav'
min_silence_duration_ms = 60  # Minimum silence duration in milliseconds (1 second)

# Split the audio into fragments
fragments = split_audio_by_silence(audio_path, min_silence_duration_ms)

# Specify the dataset folder and CSV file path
dataset_folder = 'datasetm'
csv_file = 'datasetm.csv'

# Create the dataset folder if it doesn't exist
if not os.path.exists(dataset_folder):
    os.makedirs(dataset_folder)

# Open the CSV file in write mode
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Filename', 'Duration'])  # Write header row

    # Save the fragments as WAV files and write metadata to the CSV file
    for i, fragment in enumerate(fragments):
        # Generate a unique filename for the fragment
        fragment_filename = f"fragment_{i+1}.wav"
        fragment_path = os.path.join(dataset_folder, fragment_filename)

        # Export the fragment as a WAV file
        fragment.export(fragment_path, format="wav")
        print(f"Fragment {i+1} saved as {fragment_path}")

        # Write fragment metadata to the CSV file
        duration = len(fragment) / 1000.0  # Duration in seconds
        writer.writerow([fragment_filename, duration])

print("Dataset creation complete.")
# Out:
# Fragment 1 saved as datasetm/fragment_1.wav
# Fragment 2 saved as datasetm/fragment_2.wav
# Fragment 3 saved as datasetm/fragment_3.wav
# Fragment 4 saved as datasetm/fragment_4.wav
# Fragment 5 saved as datasetm/fragment_5.wav
# Fragment 6 saved as datasetm/fragment_6.wav
# Fragment 7 saved as datasetm/fragment_7.wav
# Fragment 8 saved as datasetm/fragment_8.wav
# Fragment 9 saved as datasetm/fragment_9.wav
# Fragment 10 saved as datasetm/fragment_10.wav
# Fragment 11 saved as datasetm/fragment_11.wav
# Fragment 12 saved as datasetm/fragment_12.wav
# Fragment 13 saved as datasetm/fragment_13.wav
# Fragment 14 saved as datasetm/fragment_14.wav
# Fragment 15 saved as datasetm/fragment_15.wav
# Fragment 16 saved as datasetm/fragment_16.wav
# Fragment 17 saved as datasetm/fragment_17.wav
# Fragment 18 saved as datasetm/fragment_18.wav
# Fragment 19 saved as datasetm/fragment_19.wav
# Fragment 20 saved as datasetm/fragment_20.wav
# Fragment 21 saved as datasetm/fragment_21.wav
# Fragment 22 saved as datasetm/fragment_22.wav
# Fragment 23 saved as datasetm/fragment_23.wav
# Fragment 24 saved as datasetm/fragment_24.wav
# Fragment 25 saved as datasetm/fragment_25.wav
# Fragment 26 saved as datasetm/fragment_26.wav
# Fragment 27 saved as datasetm/fragment_27.wav
# Fragment 28 saved as datasetm/fragment_28.wav
# Fragment 29 saved as datasetm/fragment_29.wav
# Fragment 30 saved as datasetm/fragment_30.wav
# Fragment 31 saved as datasetm/fragment_31.wav
# Fragment 32 saved as datasetm/fragment_32.wav
# Fragment 33 saved as datasetm/fragment_33.wav
# Fragment 34 saved as datasetm/fragment_34.wav
# Fragment 35 saved as datasetm/fragment_35.wav
# Fragment 36 saved as datasetm/fragment_36.wav
# Fragment 37 saved as datasetm/fragment_37.wav
# Fragment 38 saved as datasetm/fragment_38.wav
# Fragment 39 saved as datasetm/fragment_39.wav
# Fragment 40 saved as datasetm/fragment_40.wav
# Fragment 41 saved as datasetm/fragment_41.wav
# Fragment 42 saved as datasetm/fragment_42.wav
# Fragment 43 saved as datasetm/fragment_43.wav
# Fragment 44 saved as datasetm/fragment_44.wav
# Fragment 45 saved as datasetm/fragment_45.wav
# Fragment 46 saved as datasetm/fragment_46.wav
# Fragment 47 saved as datasetm/fragment_47.wav
# Fragment 48 saved as datasetm/fragment_48.wav
# Fragment 49 saved as datasetm/fragment_49.wav
# Dataset creation complete.
